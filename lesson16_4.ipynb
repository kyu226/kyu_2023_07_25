# %%
import requests

url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
r = requests.get(url)
if r.status_code == 200:
    print("下載成功")
# Out:
# 下載成功

# %%
r.json()
# Out:
# {'cwaopendata': {'@xmlns': 'urn:cwa:gov:tw:cwacommon:0.1',
#   'identifier': 'e5333e43-ecd2-78c7-02eb-26694cdbdd9d',
#   'sender': 'weather@cwa.gov.tw',
#   'sent': '2023-10-04T16:27:03+08:00',
#   'status': 'Actual',
#   'msgType': 'Issue',
#   'source': 'MFC',
#   'dataid': 'C0032-001',
#   'scope': 'Public',
#   'dataset': {'datasetInfo': {'datasetDescription': '三十六小時天氣預報',
#     'issueTime': '2023-10-04T17:00:00+08:00',
#     'update': '2023-10-04T16:27:03+08:00'},
#    'location': [{'locationName': '臺北市',
#      'weatherElement': [{'elementName': 'Wx',
#        'time': [{'startTime': '2023-10-04T18:00:00+08:00',
#          'endTime': '2023-10-05T06:00:00+08:00',
#          'parameter': {'parameterName': '陰陣雨', 'parameterValue': '14'}},
#         {'startTime': '2023-10-05T06:00:00+08:00',
#          'endTime': '2023-10-05T18:00:00+08:00',
#          'parameter': {'parameterName': '陰陣雨', 'parameterValue': '14'}},
#         {'startTime': '2023-10-05T18:00:00+08:00',
# ...

# %%
all_json = r.json()
locations = all_json['cwaopendata']['dataset']['location']
weather_list=[]
for item in locations:
    city_item={}
    city_item['城市'] = item['locationName'] 
    city_item['起始時間']=item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間']=item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度']=item['weatherElement'][1]['time'][0]['parameter']['parameterName']
    city_item['對低溫度']=item['weatherElement'][2]['time'][0]['parameter']['parameterName']
    city_item['感覺']=item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)

weather_list
# Out:
# [{'城市': '臺北市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '27',
#   '對低溫度': '27',
#   '感覺': '舒適'},
#  {'城市': '新北市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '27',
#   '對低溫度': '26',
#   '感覺': '舒適'},
#  {'城市': '桃園市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '26',
#   '對低溫度': '26',
#   '感覺': '舒適'},
#  {'城市': '臺中市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '29',
#   '對低溫度': '28',
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺南市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '28',
#   '對低溫度': '27',
#   '感覺': '舒適'},
#  {'城市': '高雄市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
#   '結束時間': '2023-10-05T06:00:00+08:00',
#   '最高溫度': '29',
#   '對低溫度': '27',
#   '感覺': '舒適至悶熱'},
#  {'城市': '基隆市',
#   '起始時間': '2023-10-04T18:00:00+08:00',
# ...

# %%
import pandas as pd 
weather_df = pd.DataFrame(weather_list)
weather_df
# Out:
#      城市                       起始時間                       結束時間 最高溫度 對低溫度     感覺
# 0   臺北市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   27   27     舒適
# 1   新北市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   27   26     舒適
# 2   桃園市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   26   26     舒適
# 3   臺中市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   29   28  舒適至悶熱
# 4   臺南市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   28   27     舒適
# 5   高雄市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   29   27  舒適至悶熱
# 6   基隆市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   28   27  舒適至悶熱
# 7   新竹縣  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   27   26  舒適至悶熱
# 8   新竹市  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   27   26     舒適
# 9   苗栗縣  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   27   26  舒適至悶熱
# 10  彰化縣  2023-10-04T18:00:00+08:00  2023-10-05T06:00:00+08:00   28   27     舒適
# ...
