# %%
import random
def getscore():
    score=[]
    for i in range(5):
        score.append(random.randint(50,100))
    return score

students=[]
for i in range(50):
    scores=getscore()
    students.append(scores)

students
# Out:
# [[65, 99, 77, 91, 100],
#  [65, 56, 81, 56, 58],
#  [66, 82, 52, 70, 57],
#  [51, 99, 70, 66, 82],
#  [52, 69, 61, 89, 98],
#  [60, 96, 69, 100, 57],
#  [79, 81, 63, 70, 50],
#  [75, 53, 51, 81, 69],
#  [76, 52, 79, 79, 89],
#  [84, 90, 91, 83, 58],
#  [58, 84, 77, 60, 52],
#  [78, 63, 96, 78, 78],
#  [56, 65, 100, 70, 59],
#  [60, 62, 99, 78, 98],
#  [63, 55, 91, 86, 95],
#  [52, 85, 52, 85, 52],
#  [59, 58, 53, 54, 59],
#  [85, 82, 88, 70, 92],
#  [98, 59, 76, 73, 76],
#  [86, 91, 95, 65, 97],
#  [83, 54, 62, 94, 70],
#  [90, 92, 99, 90, 77],
#  [66, 95, 74, 92, 51],
#  [58, 73, 81, 64, 62],
#  [80, 53, 86, 72, 52],
#  [62, 77, 62, 77, 71],
#  [84, 52, 83, 51, 72],
#  [96, 63, 80, 76, 68],
#  [68, 61, 92, 99, 56],
#  [83, 51, 88, 100, 65],
#  [80, 65, 74, 56, 65],
#  [67, 97, 85, 89, 67],
#  [70, 94, 73, 64, 96],
#  [85, 90, 96, 77, 50],
#  [62, 94, 88, 78, 99],
#  [84, 83, 58, 82, 61],
#  [86, 62, 76, 75, 99],
#  [72, 57, 65, 74, 80],
#  [52, 65, 76, 83, 59],
# ...
